# %% [markdown]
# # Notes for Panda

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.3'

# %%
# read the olimpics.csv
oo = pd.read_csv('./data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# # Infos
# Show the dimensions of dataset

# %%
print(f"Row {oo.shape[0]} Columns {oo.shape[1]}")
# Out:
# Row 29216 Columns 10

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# # Basic analysis

# %% [markdown]
# value_counts() shows which value appears more time

# %%
oo['Edition'].value_counts() # oo.Edition.value_counts() works too
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo[['Gender','Edition']].value_counts()
# Out:
# Gender  Edition
# Men     1920       1255
#         2000       1126
#         2008       1110
#         1992       1105
#         2004       1099
#         1996       1082
#         1988       1011
#         1984        973
#         1980        958
#         1972        947
# Women   2008        932
# Men     1976        924
# Women   2004        899
#         2000        889
# Men     1912        855
#         1924        833
#         1964        820
#         1968        819
#         1936        791
#         1908        789
# Women   1996        777
# Men     1952        750
#         1956        739
#         1960        737
#         1948        718
#         1928        615
# Women   1992        600
# Men     1932        555
# Women   1988        535
# Men     1900        501
# Women   1984        486
# Men     1904        458
# Women   1980        429
#         1976        381
#         1972        238
#         1968        212
#         1964        190
# ...

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# #### Usage of booleans into conditions

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# #### String handling

# %% [markdown]
# oo[oo.Athlete.str.contains("Maria")]

# %%
oo[oo.Athlete.str.contains("OWENS, Jesse")]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %% [markdown]
# ## Loc and iLoc

# %%
oo.loc[700]
# Out:
# City                          St Louis
# Edition                           1904
# Sport                         Aquatics
# Discipline                    Swimming
# Athlete               DANIELS, Charles
# NOC                                USA
# Gender                             Men
# Event           50y freestyle (45.72m)
# Event_gender                         M
# Medal                           Bronze
# Name: 700, dtype: object

# %%
oo.set_index("Athlete",inplace=True)

# %%
oo.loc["BOLT, Usain"]
# Out:
#                 City  Edition      Sport Discipline  NOC Gender         Event  \
# Athlete
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          100m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men          200m
# BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men  4x100m relay
#
#             Event_gender Medal
# Athlete
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold
# BOLT, Usain            M  Gold

# %%
oo.reset_index(inplace=True)

# %%
oo.head()
# Out:
#    index             Athlete    City  Edition     Sport Discipline  NOC  \
# 0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN
# 1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT
# 2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE
# 3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE
# 4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
oo.index[54]
# Out:
# 54

# %%
lo = oo[oo.Edition == 2008]

# %%
lo.head()
# Out:
#        index           Athlete     City  Edition     Sport Discipline  NOC  \
# 27174  27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS
# 27175  27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS
# 27176  27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN
# 27177  27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN
# 27178  27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN
#
#       Gender         Event Event_gender   Medal
# 27174    Men  10m platform            M  Bronze
# 27175    Men  10m platform            M    Gold
# 27176    Men  10m platform            M  Silver
# 27177  Women  10m platform            W  Bronze
# 27178  Women  10m platform            W    Gold
